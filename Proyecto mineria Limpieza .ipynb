# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import seaborn as sns

# %%
df = pd.read_csv("WC2019.csv")
df.head()
# Out:
#     gameid                                                url league   split  \
# 0  1070340  https://matchhistory.euw.leagueoflegends.com/e...     WC  2019-W
# 1  1070340  https://matchhistory.euw.leagueoflegends.com/e...     WC  2019-W
# 2  1070340  https://matchhistory.euw.leagueoflegends.com/e...     WC  2019-W
# 3  1070340  https://matchhistory.euw.leagueoflegends.com/e...     WC  2019-W
# 4  1070340  https://matchhistory.euw.leagueoflegends.com/e...     WC  2019-W
#
#           date   week game patchno  playerid  side  ... gdat15 xpat10  \
# 0  43740,28615  PI-RR    1    9,19         1  Blue  ...   -798   4530
# 1  43740,28615  PI-RR    1    9,19         2  Blue  ...  -1366   3679
# 2  43740,28615  PI-RR    1    9,19         3  Blue  ...   -629   4751
# 3  43740,28615  PI-RR    1    9,19         4  Blue  ...  -1829   3526
# 4  43740,28615  PI-RR    1    9,19         5  Blue  ...  -1156   2731
#
#   oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15 csdat15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 98 columns):
# gameid                     1428 non-null int64
# url                        1428 non-null object
# league                     1428 non-null object
# split                      1428 non-null object
# date                       1428 non-null object
# week                       1428 non-null object
# game                       1428 non-null object
# patchno                    1428 non-null object
# playerid                   1428 non-null int64
# side                       1428 non-null object
# position                   1428 non-null object
# player                     1428 non-null object
# team                       1428 non-null object
# champion                   1428 non-null object
# ban1                       1428 non-null object
# ban2                       1428 non-null object
# ban3                       1428 non-null object
# ...

# %%
df.shape
# Out:
# (1428, 98)

# %%
msno.matrix(df)

# %%
for column in df:
    print("----------*----------*----------*----------*----------*----------*----------*----------")
    print("Columna: ", column)
    print("Número de valores únicos: ", df[column].nunique())
    print("Valores únicos: ", df[column].unique())
    print("Conteo de valores", df[column].value_counts())
# Out:
# ----------*----------*----------*----------*----------*----------*----------*----------
# Columna:  gameid
# Número de valores únicos:  119
# Valores únicos:  [1070340 1070330 1070349 1070359 1070365 1070378 1070393 1070420 1070445
#  1070457 1070463 1070475 1070531 1070547 1070555 1070569 1070580 1070599
#  1070624 1070668 1060543 1060559 1060585 1060612 1060652 1060665 1070918
#  1070910 1070920 1070922 1060775 1060784 1060790 1070971 1070985 1070986
#  1070996 1071000 1071009 1071014 1071024 1071025 1061005 1061019 1061026
#  1061031 1061043 1061051 1071246 1071259 1071266 1071272 1071286 1071297
#  1061143 1061147 1061156 1061161 1061175 1061189 1061209 1061221 1071398
#  1071409 1071415 1061227 1071461 1071479 1071486 1071491 1071497 1071502
#  1071514 1071536 1071527 1071547 1071552 1071560 1071569 1071575 1071615
#  1071627 1071642 1071659 1071668 1071675 1071696 1071705 1071716 1071720
#  1071724 1071731 1061881 1061934 1061950 1061960 1061976 1072089 1072107
# ...

# %%
df.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df=df.drop(['url', 'league','split','date','week','game','patchno','fb','fbassist','fbvictim','fbtime','okpm','ckpm','fd','oppdragkills','elementals','oppelementals','oppelders','herald','heraldtime','visiblewardclearrate','invisiblewardclearrate','oppgoldat10','oppgoldat15','oppxpat10','oppcsat10','oppcsat15'], axis=1)

# %%
df.head()
# Out:
#     gameid  playerid  side position   player                team  champion  \
# 0  1070340         1  Blue      Top      Evi  DetonatioN FocusMe      Gnar
# 1  1070340         2  Blue   Jungle    Steal  DetonatioN FocusMe      Ekko
# 2  1070340         3  Blue   Middle    Ceros  DetonatioN FocusMe  Nocturne
# 3  1070340         4  Blue      ADC  Yutapon  DetonatioN FocusMe    Lucian
# 4  1070340         5  Blue  Support    Gaeng  DetonatioN FocusMe    Thresh
#
#      ban1       ban2   ban3  ... goldat10 gdat10 goldat15  gdat15  xpat10  \
# 0  Qiyana  Gangplank  Akali  ...     3078   -362     4670    -798    4530
# 1  Qiyana  Gangplank  Akali  ...     3684   -371     4912   -1366    3679
# 2  Qiyana  Gangplank  Akali  ...     3926    357     5487    -629    4751
# 3  Qiyana  Gangplank  Akali  ...     3579   -390     5313   -1829    3526
# 4  Qiyana  Gangplank  Akali  ...     2088   -306     3163   -1156    2731
#
#    xpdat10  csat10  csdat10  csat15 csdat15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 71 columns):
# gameid                     1428 non-null int64
# playerid                   1428 non-null int64
# side                       1428 non-null object
# position                   1428 non-null object
# player                     1428 non-null object
# team                       1428 non-null object
# champion                   1428 non-null object
# ban1                       1428 non-null object
# ban2                       1428 non-null object
# ban3                       1428 non-null object
# ban4                       1428 non-null object
# ban5                       1422 non-null object
# gamelength                 1428 non-null object
# result                     1428 non-null int64
# k                          1428 non-null int64
# d                          1428 non-null int64
# a                          1428 non-null int64
# ...

# %%
df.shape
# Out:
# (1428, 71)

# %%
msno.matrix(df)

# %%
for column in df:
    print("----------*----------*----------*----------*----------*----------*----------*----------")
    print("Columna: ", column)
    print("Número de valores únicos: ", df[column].nunique())
    print("Valores únicos: ", df[column].unique())
    print("Conteo de valores", df[column].value_counts())
# Out:
# ----------*----------*----------*----------*----------*----------*----------*----------
# Columna:  gameid
# Número de valores únicos:  119
# Valores únicos:  [1070340 1070330 1070349 1070359 1070365 1070378 1070393 1070420 1070445
#  1070457 1070463 1070475 1070531 1070547 1070555 1070569 1070580 1070599
#  1070624 1070668 1060543 1060559 1060585 1060612 1060652 1060665 1070918
#  1070910 1070920 1070922 1060775 1060784 1060790 1070971 1070985 1070986
#  1070996 1071000 1071009 1071014 1071024 1071025 1061005 1061019 1061026
#  1061031 1061043 1061051 1071246 1071259 1071266 1071272 1071286 1071297
#  1061143 1061147 1061156 1061161 1061175 1061189 1061209 1061221 1071398
#  1071409 1071415 1061227 1071461 1071479 1071486 1071491 1071497 1071502
#  1071514 1071536 1071527 1071547 1071552 1071560 1071569 1071575 1071615
#  1071627 1071642 1071659 1071668 1071675 1071696 1071705 1071716 1071720
#  1071724 1071731 1061881 1061934 1061950 1061960 1061976 1072089 1072107
# ...

# %%
df.columns
# Out:
# Index(['gameid', 'playerid', 'side', 'position', 'player', 'team', 'champion',
#        'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k',
#        'd', 'a', 'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras',
#        'pentas', 'kpm', 'fdtime', 'teamdragkills', 'firedrakes', 'waterdrakes',
#        'earthdrakes', 'airdrakes', 'elders', 'ft', 'fttime', 'firstmidouter',
#        'firsttothreetowers', 'teamtowerkills', 'opptowerkills', 'fbaron',
#        'fbarontime', 'teambaronkills', 'oppbaronkills', 'dmgtochamps',
#        'dmgtochampsperminute', 'dmgshare', 'earnedgoldshare', 'wards', 'wpm',
#        'wardshare', 'wardkills', 'wcpm', 'visionwards', 'visionwardbuys',
#        'totalgold', 'earnedgpm', 'goldspent', 'gspd', 'minionkills',
#        'monsterkills', 'monsterkillsownjungle', 'monsterkillsenemyjungle',
#        'cspm', 'goldat10', 'gdat10', 'goldat15', 'gdat15', 'xpat10', 'xpdat10',
#        'csat10', 'csdat10', 'csat15', 'csdat15'],
# ...

# %%
df.drop(['playerid'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     gameid  side position   player                team  champion    ban1  \
# 0  1070340  Blue      Top      Evi  DetonatioN FocusMe      Gnar  Qiyana
# 1  1070340  Blue   Jungle    Steal  DetonatioN FocusMe      Ekko  Qiyana
# 2  1070340  Blue   Middle    Ceros  DetonatioN FocusMe  Nocturne  Qiyana
# 3  1070340  Blue      ADC  Yutapon  DetonatioN FocusMe    Lucian  Qiyana
# 4  1070340  Blue  Support    Gaeng  DetonatioN FocusMe    Thresh  Qiyana
#
#         ban2   ban3   ban4  ... goldat10 gdat10  goldat15  gdat15  xpat10  \
# 0  Gangplank  Akali  Elise  ...     3078   -362      4670    -798    4530
# 1  Gangplank  Akali  Elise  ...     3684   -371      4912   -1366    3679
# 2  Gangplank  Akali  Elise  ...     3926    357      5487    -629    4751
# 3  Gangplank  Akali  Elise  ...     3579   -390      5313   -1829    3526
# 4  Gangplank  Akali  Elise  ...     2088   -306      3163   -1156    2731
#
#    xpdat10  csat10  csdat10 csat15 csdat15
# ...

# %%
df.drop(df[df['position']=='Team'].index, inplace=True)

# %%
for column in df:
    print("----------*----------*----------*----------*----------*----------*----------*----------")
    print("Columna: ", column)
    print("Número de valores únicos: ", df[column].nunique())
    print("Valores únicos: ", df[column].unique())
    print("Conteo de valores", df[column].value_counts())
# Out:
# ----------*----------*----------*----------*----------*----------*----------*----------
# Columna:  gameid
# Número de valores únicos:  119
# Valores únicos:  [1070340 1070330 1070349 1070359 1070365 1070378 1070393 1070420 1070445
#  1070457 1070463 1070475 1070531 1070547 1070555 1070569 1070580 1070599
#  1070624 1070668 1060543 1060559 1060585 1060612 1060652 1060665 1070918
#  1070910 1070920 1070922 1060775 1060784 1060790 1070971 1070985 1070986
#  1070996 1071000 1071009 1071014 1071024 1071025 1061005 1061019 1061026
#  1061031 1061043 1061051 1071246 1071259 1071266 1071272 1071286 1071297
#  1061143 1061147 1061156 1061161 1061175 1061189 1061209 1061221 1071398
#  1071409 1071415 1061227 1071461 1071479 1071486 1071491 1071497 1071502
#  1071514 1071536 1071527 1071547 1071552 1071560 1071569 1071575 1071615
#  1071627 1071642 1071659 1071668 1071675 1071696 1071705 1071716 1071720
#  1071724 1071731 1061881 1061934 1061950 1061960 1061976 1072089 1072107
# ...

# %%
msno.matrix(df)

# %% [markdown]
# Vale la pena eliminar mas la culumna de first blood baron o eliminar los partidos que estan incompleotos?????

# %%
df=df.dropna()

# %%
msno.matrix(df)

# %%
df.to_csv("ProyecoReady.csv", index=False)
